# %%
import os
import math

# %%
def get_label(longname):
    """
    Convert a long name to a short version
    """
    filename = os.path.basename(longname)  # Extract filename only
    return filename if len(filename) <= 10 else filename[:7] + '...'

def get_rel_paths(here_path, root_path):
    """
    Given the current full path and the root path, return the
    relative path to the directory above, and the relative path
    to this full path
    """
    rel_path = os.path.relpath(here_path, root_path) # Compute relative path

    if here_path == root_path:  # Special case: same directory
        return ('..', '.')
    
    parts = rel_path.split(os.sep)  # Split the path into components

    if len(parts) == 1:  # Special case: Direct child of parent_dir
        return ('.', parts[0])
    
    return (parts[0], rel_path)  # General case


def remove_excluded_subdirs(dir_list):
    """
    For os.path.walk(), we can restrict the branches that get traversed by changing
    the list which walk() returns as 'subdirs'.  Remember that when we are editing
    that list, we are actually changing the memory representation inside the walk()
    generator, so the semantics are a little tricky.  For example, we can't simultaneously
    loop over the list and edit it.  I'll give you a working function for this task
    to avoid confusion.
    
    This function removes 'reveal.js', '.git', and anything starting with '_' from the list.
    """
    more_names_to_remove = [elt for elt in dir_list if elt.startswith('_')][:]
    for nm in ['reveal.js', '.git'] + more_names_to_remove:
        if nm in dir_list:
            dir_list.remove(nm)

def show_this_leaf(nm):
    """
    Use this function to return False for leaf node names you don't want to draw.
    """
    # Exclude nodes starting with '.' or '_' or ending with '~' or starting with '#'
    if nm.startswith(('.', '_')) or nm.endswith('~') or nm.startswith('#'):
        return False  # Don't show this leaf node

    return True  # If the node passes the filter, show it

seen_edges = set()

class Node():
    def __init__(self, parent_node, name):
        """
        parent_node should be the Node instance of the parent.
        
        name is a long name, like a full relative path.  It needs to be
        unique for all nodes in the tree.
        
        Note how we make a connection to the parent node when this node is created.
        """
        self.parent = parent_node
        if self.parent is not None:
            self.parent._add_kid(self)
        self.name = name
        self.label = get_label(self.name)
        self.kids = []
        self.descendant_count = 0
    def _add_kid(self, kid_node):
        self.kids.append(kid_node)
    def add_descendant_to_all_ancestors(self):
        """
        Modify this function so that when it is called for a node's parent,
        that parent and all ancestors get their descendant_count incremented.
        """

        node = self  # Start at self 
        while node is not None:
            node.descendant_count += 1  # Increment count for ancestors
            node = node.parent  # Move up to the next ancestor
    
    def count_descendants(self):
        """Recursive method to count all descendants."""
        self.descendant_count = len(self.kids)  # Reset descendant count
        # print(f"Counting descendants for node {self.name}, initial count: {self.descendant_count}")
        for kid in self.kids:
            self.descendant_count += kid.count_descendants()  # Recursively count
            # print(f"Node {self.name} has {self.descendant_count} descendants.")
        return self.descendant_count
    
    def get_node_attributes(self):
        """
        Returns attributes for the node based on the type of the node and its filename.
        """
        # Determine shape based on whether it's a leaf node or not
        shape = "rect" if len(self.kids) == 0 else "ellipse"  # Leaf nodes are rect, others are ellipse
        
        # Determine color based on the file extension
        if self.name.endswith(('.png', '.jpg', '.svg')):
            fillcolor = "blue"
        else:
            fillcolor = "lightgray"
        
        # Return the attributes in a format suitable for Graphviz
        return {
            "shape": shape,
            "fillcolor": fillcolor,
            "style": "filled"  # This ensures the background is filled with the color
        }

    
    def write_node(self, indent=0):
        """Write the DOT code to define a single node."""
        # Determine the shape and fillcolor based on the node type
        attributes = self.get_node_attributes()  # Get the node attributes
        # Update the node's DOT attributes with shape, fillcolor, and style
        print(f'{indent*" "}"{self.name}" [label="{self.label}" shape={attributes["shape"]} ' 
            f'fillcolor={attributes["fillcolor"]} style={attributes["style"]}];')

    
    def traverse_node_defs(self, indent=0):
        """
        Write the DOT code that defines this Node and all its descendants.
        
        Here and in traverse_edge_defs(), 'indent' just helps with formatting
        when writing out the DOT code.
        """
        self.write_node(indent=indent) # Write the current node's definition
        for kid in self.kids:
            kid.traverse_node_defs(indent+4) # Recursively write definitions for the children

    def write_incoming_edge(self, this_parent, indent=0):
            """
            Calculate edge width based on the square root of descendants.
            """
            if this_parent.descendant_count > 0:
                width = round(this_parent.descendant_count ** 0.5, 2)
            else:
                width = 1  # Default width if no descendants
            edge = (this_parent.name, self.name)
            if edge not in seen_edges:
                # Compute the penwidth based on the square root of the descendant count.
                penwidth = math.sqrt(self.descendant_count) if self.descendant_count > 0 else 1
                print(f'{indent*" "}"{this_parent.name}" -> "{self.name}" [penwidth={penwidth}];')
                seen_edges.add(edge)
            

    def traverse_edge_defs(self, indent=0):
        """
        Write the DOT code that defines the incoming edges for this Node and
        all its descendants.
        
        Here and in traverse_node_defs(), 'indent' just helps with formatting
        when writing out the DOT code.
        """
        for kid in self.kids:
            kid.write_incoming_edge(self, indent=indent + 4)  # Write edges
            kid.traverse_edge_defs(indent + 4)  # Recursively process children


# Maintain a dictionary of Nodes so that we can find them by name.  Use
# paths relative to the root as keys- so the very first key is just '.'
nodes = {}
root_path = 'CMU-MS-DAS-Vis-S25/docs'
root_node = Node(None, '.')
nodes['.'] = root_node

# Walk the tree
for dirname, subdirs, files in os.walk(root_path):
    remove_excluded_subdirs(subdirs)
    rel_dir_path, rel_path = get_rel_paths(dirname, root_path)
    if rel_path in nodes:
        # This happens on the very first node
        dir_node = nodes[rel_path]
    else:
        assert rel_dir_path in nodes
        dir_node= Node(nodes[rel_dir_path], rel_path)
        nodes[rel_path] = dir_node

    # Add nodes for all the children of this dir
    for file in files:
        if show_this_leaf(file):
            full_path = os.path.join(dirname, file)
            ignore_this, rel_path = get_rel_paths(full_path, root_path)
            this_node = Node(dir_node, rel_path)
            nodes[rel_path] = this_node

# Calculate number of descendants for all nodes
for node in nodes:
    nodes[node].add_descendant_to_all_ancestors()

# Write out the Dot code
print("digraph {")
root_node.traverse_node_defs()
root_node.traverse_edge_defs()
print("}")
# Out:
# digraph {
# "." [label="." shape=ellipse fillcolor=lightgray style=filled];
#     "assignment_matplotlib.html" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_maps_body.md" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "idioms_for_statistics.html" [label="idioms_..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_ipywidgets_body.md" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_ggplot.html" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "graphs_with_nodes_and_edges.html" [label="graphs_..." shape=rect fillcolor=lightgray style=filled];
#     "overview.md" [label="overvie..." shape=rect fillcolor=lightgray style=filled];
#     "git_and_github.html" [label="git_and..." shape=rect fillcolor=lightgray style=filled];
#     "ipywidgets_intro.html" [label="ipywidg..." shape=rect fillcolor=lightgray style=filled];
#     "dashboards_body.md" [label="dashboa..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_ggplot_body.md" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_seaborn_body.md" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "marching_squares.html" [label="marchin..." shape=rect fillcolor=lightgray style=filled];
#     "maps.html" [label="maps.html" shape=rect fillcolor=lightgray style=filled];
#     "why_vis.html" [label="why_vis..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_matplotlib_body.md" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "welcome_to_d3_body.md" [label="welcome..." shape=rect fillcolor=lightgray style=filled];
#     "maps_body.md" [label="maps_bo..." shape=rect fillcolor=lightgray style=filled];
#     "course_intro_body.md" [label="course_..." shape=rect fillcolor=lightgray style=filled];
#     "my_notes_body.md" [label="my_note..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_ipywidgets.html" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "thinking_about_coordinates_body.md" [label="thinkin..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_visit_movie.html" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "data_manifolds.html" [label="data_ma..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_seaborn.html" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "using_color_body.md" [label="using_c..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_node_edge_graphs.html" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "welcome_to_d3.html" [label="welcome..." shape=rect fillcolor=lightgray style=filled];
#     "data_manifolds_body.md" [label="data_ma..." shape=rect fillcolor=lightgray style=filled];
#     "graphs_with_nodes_and_edges_body.md" [label="graphs_..." shape=rect fillcolor=lightgray style=filled];
#     "sci_vis_algorithms.html" [label="sci_vis..." shape=rect fillcolor=lightgray style=filled];
#     "sci_vis_algorithms_body.md" [label="sci_vis..." shape=rect fillcolor=lightgray style=filled];
#     "ipywidgets_intro_body.md" [label="ipywidg..." shape=rect fillcolor=lightgray style=filled];
#     "you_need_multiple_venvs_body.md" [label="you_nee..." shape=rect fillcolor=lightgray style=filled];
#     "assignment_maps.html" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "visit_body.md" [label="visit_b..." shape=rect fillcolor=lightgray style=filled];
#     "index.md" [label="index.md" shape=rect fillcolor=lightgray style=filled];
#     "assignment_node_edge_graphs_body.md" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "dashboards.html" [label="dashboa..." shape=rect fillcolor=lightgray style=filled];
#     "my_notes.html" [label="my_note..." shape=rect fillcolor=lightgray style=filled];
#     "idioms_for_statistics_body.md" [label="idioms_..." shape=rect fillcolor=lightgray style=filled];
#     "grammar_of_graphics_body.md" [label="grammar..." shape=rect fillcolor=lightgray style=filled];
#     "why_vis_body.md" [label="why_vis..." shape=rect fillcolor=lightgray style=filled];
#     "visit.html" [label="visit.html" shape=rect fillcolor=lightgray style=filled];
#     "assignment_visit_movie_body.md" [label="assignm..." shape=rect fillcolor=lightgray style=filled];
#     "git_and_github_body.md" [label="git_and..." shape=rect fillcolor=lightgray style=filled];
#     "marching_squares_body.md" [label="marchin..." shape=rect fillcolor=lightgray style=filled];
#     "you_need_multiple_venvs.html" [label="you_nee..." shape=rect fillcolor=lightgray style=filled];
#     "grammar_of_graphics.html" [label="grammar..." shape=rect fillcolor=lightgray style=filled];
#     "course_intro.html" [label="course_..." shape=rect fillcolor=lightgray style=filled];
#     "now_we_need_a_web_server.html" [label="now_we_..." shape=rect fillcolor=lightgray style=filled];
#     "now_we_need_a_web_server_body.md" [label="now_we_..." shape=rect fillcolor=lightgray style=filled];
#     "using_color.html" [label="using_c..." shape=rect fillcolor=lightgray style=filled];
#     "thinking_about_coordinates.html" [label="thinkin..." shape=rect fillcolor=lightgray style=filled];
#     "css" [label="css" shape=ellipse fillcolor=lightgray style=filled];
#         "css/white.css" [label="white.css" shape=rect fillcolor=lightgray style=filled];
#     "images" [label="images" shape=ellipse fillcolor=lightgray style=filled];
#         "images/simple_graph_svg_example.png" [label="simple_..." shape=rect fillcolor=blue style=filled];
#         "images/PA_FIPS_zoomed.png" [label="PA_FIPS..." shape=rect fillcolor=blue style=filled];
#         "images/StormTotalSnowWeb.jpg" [label="StormTo..." shape=rect fillcolor=blue style=filled];
#         "images/simple_stacked_line_graph.png" [label="simple_..." shape=rect fillcolor=blue style=filled];
#         "images/isosurface_colin_1.png" [label="isosurf..." shape=rect fillcolor=blue style=filled];
#         "images/800px-Australian_Census_2011_demographic_map_-_Australia_by_SLA_-_BCP_field_2715_Christianity_Anglican_Persons.svg.png" [label="800px-A..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_case_2a.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/pa_travel_loop.png" [label="pa_trav..." shape=rect fillcolor=blue style=filled];
#         "images/simple_color_mapped_image.png" [label="simple_..." shape=rect fillcolor=blue style=filled];
#         "images/Time_Curve_Of_A_Statistical_Range.png" [label="Time_Cu..." shape=rect fillcolor=blue style=filled];
#         "images/VaccineChoice.png" [label="Vaccine..." shape=rect fillcolor=blue style=filled];
#         "images/time_courses_with_iqr.png" [label="time_co..." shape=rect fillcolor=blue style=filled];
#         "images/simple_contour_plot.png" [label="simple_..." shape=rect fillcolor=blue style=filled];
#         "images/pgh_topo_cmap_difference.png" [label="pgh_top..." shape=rect fillcolor=blue style=filled];
#         "images/isosurface_colin_2.png" [label="isosurf..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_case_2b.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/isosurface_colin_1_zoom.png" [label="isosurf..." shape=rect fillcolor=blue style=filled];
#         "images/transformation-Mercator-navigation-projection.jpg" [label="transfo..." shape=rect fillcolor=blue style=filled];
#         "images/abscomb_by_seaborn.png" [label="abscomb..." shape=rect fillcolor=blue style=filled];
#         "images/marching_cubes_cases_c3_c19.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/git_history_graph.png" [label="git_his..." shape=rect fillcolor=blue style=filled];
#         "images/mario_motion_illusion.gif" [label="mario_m..." shape=rect fillcolor=lightgray style=filled];
#         "images/stacked_bar_charts_showing_changes.png" [label="stacked..." shape=rect fillcolor=blue style=filled];
#         "images/allegheny_census_tracts.png" [label="alleghe..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_putting_cells_together.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/PA_FIPS.png" [label="PA_FIPS..." shape=rect fillcolor=blue style=filled];
#         "images/800px-Equirectangular_projection_SW.jpg" [label="800px-E..." shape=rect fillcolor=blue style=filled];
#         "images/browser_server_kernel_widget.png" [label="browser..." shape=rect fillcolor=blue style=filled];
#         "images/fibers_on_manifold_gradient.png" [label="fibers_..." shape=rect fillcolor=blue style=filled];
#         "images/Streamlines.png" [label="Streaml..." shape=rect fillcolor=blue style=filled];
#         "images/Simple_Flask_Application.svg" [label="Simple_..." shape=rect fillcolor=blue style=filled];
#         "images/volume_rendered_colin.png" [label="volume_..." shape=rect fillcolor=blue style=filled];
#         "images/dashboard_two_subj.png" [label="dashboa..." shape=rect fillcolor=blue style=filled];
#         "images/volume_rendering_color_table.png" [label="volume_..." shape=rect fillcolor=blue style=filled];
#         "images/graphviz_assignment_example.png" [label="graphvi..." shape=rect fillcolor=blue style=filled];
#         "images/vis_pipeline.png" [label="vis_pip..." shape=rect fillcolor=blue style=filled];
#         "images/marching_cubes_4and4_c8.jpg" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/marching_cubes_4and4_c9.jpg" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/dashboard_qual_tbl.png" [label="dashboa..." shape=rect fillcolor=blue style=filled];
#         "images/isosurface_fluid_temp.jpg" [label="isosurf..." shape=rect fillcolor=blue style=filled];
#         "images/xkcd_git.png" [label="xkcd_gi..." shape=rect fillcolor=blue style=filled];
#         "images/compact_graphs_2x.png" [label="compact..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_case_3.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/VaccineChoicePubFigure.png" [label="Vaccine..." shape=rect fillcolor=blue style=filled];
#         "images/streamlit_graphviz_app.png" [label="streaml..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_case_4_rule_2.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/preconscious_vs_conscious_bandwidths.png" [label="precons..." shape=rect fillcolor=blue style=filled];
#         "images/ScagnosticsExampleSplom.svg" [label="Scagnos..." shape=rect fillcolor=blue style=filled];
#         "images/colin_3d_isosurfaces.png" [label="colin_3..." shape=rect fillcolor=blue style=filled];
#         "images/VaccineChoiceManuscriptCode2.png" [label="Vaccine..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_case_2_both.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/Ishihara-test---numerals.gif" [label="Ishihar..." shape=rect fillcolor=lightgray style=filled];
#         "images/myproj_graphviz_page.png" [label="myproj_..." shape=rect fillcolor=blue style=filled];
#         "images/VaccineChoiceManuscriptCode.png" [label="Vaccine..." shape=rect fillcolor=blue style=filled];
#         "images/joel_fft.png" [label="joel_ff..." shape=rect fillcolor=blue style=filled];
#         "images/fibers_on_manifold.png" [label="fibers_..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_case_4_rule_1.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/simple_stacked_bar_chart.png" [label="simple_..." shape=rect fillcolor=blue style=filled];
#         "images/dashboard_status_fig.png" [label="dashboa..." shape=rect fillcolor=blue style=filled];
#         "images/allegheny_census_tracts_zoomed.png" [label="alleghe..." shape=rect fillcolor=blue style=filled];
#         "images/joel_real.png" [label="joel_re..." shape=rect fillcolor=blue style=filled];
#         "images/SnowAmt10Prcntl.jpg" [label="SnowAmt..." shape=rect fillcolor=blue style=filled];
#         "images/marching_squares_case_one.png" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/draw_slice_z_with_slider.png" [label="draw_sl..." shape=rect fillcolor=blue style=filled];
#         "images/visual_processing.png" [label="visual_..." shape=rect fillcolor=blue style=filled];
#         "images/isosurface_show_triangles.png" [label="isosurf..." shape=rect fillcolor=blue style=filled];
#         "images/cube_of_cubes.png" [label="cube_of..." shape=rect fillcolor=blue style=filled];
#         "images/Minard.png" [label="Minard.png" shape=rect fillcolor=blue style=filled];
#         "images/ECEF_ENU_Longitude_Latitude_relationships.svg" [label="ECEF_EN..." shape=rect fillcolor=blue style=filled];
#         "images/isosurface_colin_2_zoom.png" [label="isosurf..." shape=rect fillcolor=blue style=filled];
#         "images/marching_cubes_4and4_c10.jpg" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/minard_with_plotnine.png" [label="minard_..." shape=rect fillcolor=blue style=filled];
#         "images/git_index_state.png" [label="git_ind..." shape=rect fillcolor=blue style=filled];
#         "images/visit_anim_frame_0.png" [label="visit_a..." shape=rect fillcolor=blue style=filled];
#         "images/SnowAmt90Prcntl.jpg" [label="SnowAmt..." shape=rect fillcolor=blue style=filled];
#         "images/marching_cubes_4and4_c11.jpg" [label="marchin..." shape=rect fillcolor=blue style=filled];
#         "images/world_reproj_mercator.png" [label="world_r..." shape=rect fillcolor=blue style=filled];
#         "images/joel_real_and_fft.png" [label="joel_re..." shape=rect fillcolor=blue style=filled];
#         "images/color_lookup_alg.png" [label="color_l..." shape=rect fillcolor=blue style=filled];
#         "images/isosurface_fluid_vorticity.jpg" [label="isosurf..." shape=rect fillcolor=blue style=filled];
#         "images/example_graph_4.svg" [label="example..." shape=rect fillcolor=blue style=filled];
#         "images/Streamlines2.png" [label="Streaml..." shape=rect fillcolor=blue style=filled];
#         "images/pgh_topo_relief.png" [label="pgh_top..." shape=rect fillcolor=blue style=filled];
#         "images/graphviz_test.png" [label="graphvi..." shape=rect fillcolor=blue style=filled];
#         "images/More_Complete_Flask_Application.svg" [label="More_Co..." shape=rect fillcolor=blue style=filled];
#         "images/components_of_visit.png" [label="compone..." shape=rect fillcolor=blue style=filled];
#         "images/example_graph_3.svg" [label="example..." shape=rect fillcolor=blue style=filled];
#         "images/VaccineChoiceDevFigure.png" [label="Vaccine..." shape=rect fillcolor=blue style=filled];
#         "images/hanrahan_ray_marching.png" [label="hanraha..." shape=rect fillcolor=blue style=filled];
#         "images/lighted_footprint.jpg" [label="lighted..." shape=rect fillcolor=blue style=filled];
#         "images/example_graph_2.svg" [label="example..." shape=rect fillcolor=blue style=filled];
#         "images/10.1371_journal.pone.0113838_fig_5.png" [label="10.1371..." shape=rect fillcolor=blue style=filled];
#         "images/browser_server_kernel.png" [label="browser..." shape=rect fillcolor=blue style=filled];
#         "images/pgh_topo_cmap_contoured.png" [label="pgh_top..." shape=rect fillcolor=blue style=filled];
#         "images/dashboard_all_subj.png" [label="dashboa..." shape=rect fillcolor=blue style=filled];
#         "images/pgh_topo_cmap_viridis.png" [label="pgh_top..." shape=rect fillcolor=blue style=filled];
#         "images/find_the_curved_line.jpg" [label="find_th..." shape=rect fillcolor=blue style=filled];
#         "images/pgh_topo_cmap_rainbow.png" [label="pgh_top..." shape=rect fillcolor=blue style=filled];
#         "images/elven_assassin_screencap.png" [label="elven_a..." shape=rect fillcolor=blue style=filled];
#         "images/ProbSnowGE08.jpg" [label="ProbSno..." shape=rect fillcolor=blue style=filled];
#         "images/colin_brain_contour_plot.png" [label="colin_b..." shape=rect fillcolor=blue style=filled];
#         "images/example_graph_1.svg" [label="example..." shape=rect fillcolor=blue style=filled];
#     "." -> "assignment_matplotlib.html" [penwidth=1.0];
#     "." -> "assignment_maps_body.md" [penwidth=1.0];
#     "." -> "idioms_for_statistics.html" [penwidth=1.0];
#     "." -> "assignment_ipywidgets_body.md" [penwidth=1.0];
#     "." -> "assignment_ggplot.html" [penwidth=1.0];
#     "." -> "graphs_with_nodes_and_edges.html" [penwidth=1.0];
#     "." -> "overview.md" [penwidth=1.0];
#     "." -> "git_and_github.html" [penwidth=1.0];
#     "." -> "ipywidgets_intro.html" [penwidth=1.0];
#     "." -> "dashboards_body.md" [penwidth=1.0];
#     "." -> "assignment_ggplot_body.md" [penwidth=1.0];
#     "." -> "assignment_seaborn_body.md" [penwidth=1.0];
#     "." -> "marching_squares.html" [penwidth=1.0];
#     "." -> "maps.html" [penwidth=1.0];
#     "." -> "why_vis.html" [penwidth=1.0];
#     "." -> "assignment_matplotlib_body.md" [penwidth=1.0];
#     "." -> "welcome_to_d3_body.md" [penwidth=1.0];
#     "." -> "maps_body.md" [penwidth=1.0];
#     "." -> "course_intro_body.md" [penwidth=1.0];
#     "." -> "my_notes_body.md" [penwidth=1.0];
#     "." -> "assignment_ipywidgets.html" [penwidth=1.0];
#     "." -> "thinking_about_coordinates_body.md" [penwidth=1.0];
#     "." -> "assignment_visit_movie.html" [penwidth=1.0];
#     "." -> "data_manifolds.html" [penwidth=1.0];
#     "." -> "assignment_seaborn.html" [penwidth=1.0];
#     "." -> "using_color_body.md" [penwidth=1.0];
#     "." -> "assignment_node_edge_graphs.html" [penwidth=1.0];
#     "." -> "welcome_to_d3.html" [penwidth=1.0];
#     "." -> "data_manifolds_body.md" [penwidth=1.0];
#     "." -> "graphs_with_nodes_and_edges_body.md" [penwidth=1.0];
#     "." -> "sci_vis_algorithms.html" [penwidth=1.0];
#     "." -> "sci_vis_algorithms_body.md" [penwidth=1.0];
#     "." -> "ipywidgets_intro_body.md" [penwidth=1.0];
#     "." -> "you_need_multiple_venvs_body.md" [penwidth=1.0];
#     "." -> "assignment_maps.html" [penwidth=1.0];
#     "." -> "visit_body.md" [penwidth=1.0];
#     "." -> "index.md" [penwidth=1.0];
#     "." -> "assignment_node_edge_graphs_body.md" [penwidth=1.0];
#     "." -> "dashboards.html" [penwidth=1.0];
#     "." -> "my_notes.html" [penwidth=1.0];
#     "." -> "idioms_for_statistics_body.md" [penwidth=1.0];
#     "." -> "grammar_of_graphics_body.md" [penwidth=1.0];
#     "." -> "why_vis_body.md" [penwidth=1.0];
#     "." -> "visit.html" [penwidth=1.0];
#     "." -> "assignment_visit_movie_body.md" [penwidth=1.0];
#     "." -> "git_and_github_body.md" [penwidth=1.0];
#     "." -> "marching_squares_body.md" [penwidth=1.0];
#     "." -> "you_need_multiple_venvs.html" [penwidth=1.0];
#     "." -> "grammar_of_graphics.html" [penwidth=1.0];
#     "." -> "course_intro.html" [penwidth=1.0];
#     "." -> "now_we_need_a_web_server.html" [penwidth=1.0];
#     "." -> "now_we_need_a_web_server_body.md" [penwidth=1.0];
#     "." -> "using_color.html" [penwidth=1.0];
#     "." -> "thinking_about_coordinates.html" [penwidth=1.0];
#     "." -> "css" [penwidth=1.4142135623730951];
#         "css" -> "css/white.css" [penwidth=1.0];
#     "." -> "images" [penwidth=10.14889156509222];
#         "images" -> "images/simple_graph_svg_example.png" [penwidth=1.0];
#         "images" -> "images/PA_FIPS_zoomed.png" [penwidth=1.0];
#         "images" -> "images/StormTotalSnowWeb.jpg" [penwidth=1.0];
#         "images" -> "images/simple_stacked_line_graph.png" [penwidth=1.0];
#         "images" -> "images/isosurface_colin_1.png" [penwidth=1.0];
#         "images" -> "images/800px-Australian_Census_2011_demographic_map_-_Australia_by_SLA_-_BCP_field_2715_Christianity_Anglican_Persons.svg.png" [penwidth=1.0];
#         "images" -> "images/marching_squares_case_2a.png" [penwidth=1.0];
#         "images" -> "images/pa_travel_loop.png" [penwidth=1.0];
#         "images" -> "images/simple_color_mapped_image.png" [penwidth=1.0];
#         "images" -> "images/Time_Curve_Of_A_Statistical_Range.png" [penwidth=1.0];
#         "images" -> "images/VaccineChoice.png" [penwidth=1.0];
#         "images" -> "images/time_courses_with_iqr.png" [penwidth=1.0];
#         "images" -> "images/simple_contour_plot.png" [penwidth=1.0];
#         "images" -> "images/pgh_topo_cmap_difference.png" [penwidth=1.0];
#         "images" -> "images/isosurface_colin_2.png" [penwidth=1.0];
#         "images" -> "images/marching_squares_case_2b.png" [penwidth=1.0];
#         "images" -> "images/isosurface_colin_1_zoom.png" [penwidth=1.0];
#         "images" -> "images/transformation-Mercator-navigation-projection.jpg" [penwidth=1.0];
#         "images" -> "images/abscomb_by_seaborn.png" [penwidth=1.0];
#         "images" -> "images/marching_cubes_cases_c3_c19.png" [penwidth=1.0];
#         "images" -> "images/git_history_graph.png" [penwidth=1.0];
#         "images" -> "images/mario_motion_illusion.gif" [penwidth=1.0];
#         "images" -> "images/stacked_bar_charts_showing_changes.png" [penwidth=1.0];
#         "images" -> "images/allegheny_census_tracts.png" [penwidth=1.0];
#         "images" -> "images/marching_squares_putting_cells_together.png" [penwidth=1.0];
#         "images" -> "images/PA_FIPS.png" [penwidth=1.0];
#         "images" -> "images/800px-Equirectangular_projection_SW.jpg" [penwidth=1.0];
#         "images" -> "images/browser_server_kernel_widget.png" [penwidth=1.0];
#         "images" -> "images/fibers_on_manifold_gradient.png" [penwidth=1.0];
#         "images" -> "images/Streamlines.png" [penwidth=1.0];
#         "images" -> "images/Simple_Flask_Application.svg" [penwidth=1.0];
#         "images" -> "images/volume_rendered_colin.png" [penwidth=1.0];
#         "images" -> "images/dashboard_two_subj.png" [penwidth=1.0];
#         "images" -> "images/volume_rendering_color_table.png" [penwidth=1.0];
#         "images" -> "images/graphviz_assignment_example.png" [penwidth=1.0];
#         "images" -> "images/vis_pipeline.png" [penwidth=1.0];
#         "images" -> "images/marching_cubes_4and4_c8.jpg" [penwidth=1.0];
#         "images" -> "images/marching_cubes_4and4_c9.jpg" [penwidth=1.0];
#         "images" -> "images/dashboard_qual_tbl.png" [penwidth=1.0];
#         "images" -> "images/isosurface_fluid_temp.jpg" [penwidth=1.0];
#         "images" -> "images/xkcd_git.png" [penwidth=1.0];
#         "images" -> "images/compact_graphs_2x.png" [penwidth=1.0];
#         "images" -> "images/marching_squares_case_3.png" [penwidth=1.0];
#         "images" -> "images/VaccineChoicePubFigure.png" [penwidth=1.0];
#         "images" -> "images/streamlit_graphviz_app.png" [penwidth=1.0];
#         "images" -> "images/marching_squares_case_4_rule_2.png" [penwidth=1.0];
#         "images" -> "images/preconscious_vs_conscious_bandwidths.png" [penwidth=1.0];
#         "images" -> "images/ScagnosticsExampleSplom.svg" [penwidth=1.0];
#         "images" -> "images/colin_3d_isosurfaces.png" [penwidth=1.0];
#         "images" -> "images/VaccineChoiceManuscriptCode2.png" [penwidth=1.0];
#         "images" -> "images/marching_squares_case_2_both.png" [penwidth=1.0];
#         "images" -> "images/Ishihara-test---numerals.gif" [penwidth=1.0];
#         "images" -> "images/myproj_graphviz_page.png" [penwidth=1.0];
#         "images" -> "images/VaccineChoiceManuscriptCode.png" [penwidth=1.0];
#         "images" -> "images/joel_fft.png" [penwidth=1.0];
#         "images" -> "images/fibers_on_manifold.png" [penwidth=1.0];
#         "images" -> "images/marching_squares_case_4_rule_1.png" [penwidth=1.0];
#         "images" -> "images/simple_stacked_bar_chart.png" [penwidth=1.0];
#         "images" -> "images/dashboard_status_fig.png" [penwidth=1.0];
#         "images" -> "images/allegheny_census_tracts_zoomed.png" [penwidth=1.0];
#         "images" -> "images/joel_real.png" [penwidth=1.0];
#         "images" -> "images/SnowAmt10Prcntl.jpg" [penwidth=1.0];
#         "images" -> "images/marching_squares_case_one.png" [penwidth=1.0];
#         "images" -> "images/draw_slice_z_with_slider.png" [penwidth=1.0];
#         "images" -> "images/visual_processing.png" [penwidth=1.0];
#         "images" -> "images/isosurface_show_triangles.png" [penwidth=1.0];
#         "images" -> "images/cube_of_cubes.png" [penwidth=1.0];
#         "images" -> "images/Minard.png" [penwidth=1.0];
#         "images" -> "images/ECEF_ENU_Longitude_Latitude_relationships.svg" [penwidth=1.0];
#         "images" -> "images/isosurface_colin_2_zoom.png" [penwidth=1.0];
#         "images" -> "images/marching_cubes_4and4_c10.jpg" [penwidth=1.0];
#         "images" -> "images/minard_with_plotnine.png" [penwidth=1.0];
#         "images" -> "images/git_index_state.png" [penwidth=1.0];
#         "images" -> "images/visit_anim_frame_0.png" [penwidth=1.0];
#         "images" -> "images/SnowAmt90Prcntl.jpg" [penwidth=1.0];
#         "images" -> "images/marching_cubes_4and4_c11.jpg" [penwidth=1.0];
#         "images" -> "images/world_reproj_mercator.png" [penwidth=1.0];
#         "images" -> "images/joel_real_and_fft.png" [penwidth=1.0];
#         "images" -> "images/color_lookup_alg.png" [penwidth=1.0];
#         "images" -> "images/isosurface_fluid_vorticity.jpg" [penwidth=1.0];
#         "images" -> "images/example_graph_4.svg" [penwidth=1.0];
#         "images" -> "images/Streamlines2.png" [penwidth=1.0];
#         "images" -> "images/pgh_topo_relief.png" [penwidth=1.0];
#         "images" -> "images/graphviz_test.png" [penwidth=1.0];
#         "images" -> "images/More_Complete_Flask_Application.svg" [penwidth=1.0];
#         "images" -> "images/components_of_visit.png" [penwidth=1.0];
#         "images" -> "images/example_graph_3.svg" [penwidth=1.0];
#         "images" -> "images/VaccineChoiceDevFigure.png" [penwidth=1.0];
#         "images" -> "images/hanrahan_ray_marching.png" [penwidth=1.0];
#         "images" -> "images/lighted_footprint.jpg" [penwidth=1.0];
#         "images" -> "images/example_graph_2.svg" [penwidth=1.0];
#         "images" -> "images/10.1371_journal.pone.0113838_fig_5.png" [penwidth=1.0];
#         "images" -> "images/browser_server_kernel.png" [penwidth=1.0];
#         "images" -> "images/pgh_topo_cmap_contoured.png" [penwidth=1.0];
#         "images" -> "images/dashboard_all_subj.png" [penwidth=1.0];
#         "images" -> "images/pgh_topo_cmap_viridis.png" [penwidth=1.0];
#         "images" -> "images/find_the_curved_line.jpg" [penwidth=1.0];
#         "images" -> "images/pgh_topo_cmap_rainbow.png" [penwidth=1.0];
#         "images" -> "images/elven_assassin_screencap.png" [penwidth=1.0];
#         "images" -> "images/ProbSnowGE08.jpg" [penwidth=1.0];
#         "images" -> "images/colin_brain_contour_plot.png" [penwidth=1.0];
#         "images" -> "images/example_graph_1.svg" [penwidth=1.0];
# }
